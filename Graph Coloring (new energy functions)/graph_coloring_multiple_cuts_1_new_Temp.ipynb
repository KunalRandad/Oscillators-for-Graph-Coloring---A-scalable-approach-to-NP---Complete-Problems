# %%
# !pip install lava-nc
# !pip install networkx==2.8
# !pip install matplotlib
# !pip install cvxpy
# !pip install lava-nc
# !pip install pandas
import cProfile

# %%
import lava
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
from mod_one_exchange_new import mod_one_exchange_approximation_new
from mod_one_exchange import mod_one_exchange_approximation
import graph_col_dimacs_reader as reader
import goemans_williamson_sdp as gw_sdp
import scipy
import matplotlib
import re
import time
import sys

# %%
def graph_to_mat(G, path = 'test_graphs/default2.mat'):
    # get the adjancency matrix of the graph
    adj = nx.adjacency_matrix(G).todense()
    adj = np.asarray(adj, dtype=np.int32)
    scipy.io.savemat(path, {'M': adj})   # M for matrix, to stay consistent with the .mat files we already have
    return

def mat_to_graph(path):
    mat = scipy.io.loadmat(path)
    G = nx.from_numpy_array(mat['M'])
    return G

# %%
# The file names are # dsjc125.1.col, dsjc125.5.col, dsjc250.5.col, dsjc500.1.col, dsjc500.5.col, dsjc500.9.col, dsjc1000.1.col, dsjc1000.5.col, dsjc1000.9.col, dsjr500.1c.col, dsjr500.5.col, flat300_28_0.col, flat1000_50_0.col, flat1000_60_0.col, flat1000_76_0.col, latin_square.col, le450_25c.col, le450_25d.col, myciel6.col, myciel7.col, queen6_6.col, queen77matrix.txt, r250.5.col, r1000.1c.col, r1000.5.col
# Read using dimacs

col_graph_names = ['dsjc125.1','dsjc125.5','dsjc250.5','dsjc500.1','dsjc500.5','dsjc500.9','dsjc1000.1','dsjc1000.5','dsjc1000.9','dsjr500.1c','dsjr500.5','flat300_28_0','flat1000_50_0','flat1000_60_0','flat1000_76_0','latin_square','le450_25c','le450_25d','myciel6','myciel7','queen6_6','r250.5','r1000.1c','r1000.5']


# for graph_name in col_graph_names:
#     G, adj, nnodes = reader.dimacs_reader("test_graphs/{}.col".format(graph_name))
#     # Save as .mat file
#     graph_to_mat(G, 'test_graphs/{}.mat'.format(graph_name))

# %%
from GraphColoringTest import gen_permutation_matrix, get_chr, compute_loss, gen_cyclic_graph
import GraphColoringSoln as GC
from lava.magma.core.run_configs import Loihi1SimCfg
from lava.magma.core.run_conditions import RunSteps
from lava.proc.monitor.process import Monitor


# define a function graph_painter, input would be a adjacency matrix, output should be a 1-d array of colors
def graph_painter(adj):
    # adj is a numpy array
    B = adj
    num_nodes = B.shape[0]
    conns = np.sum(B, axis=1)
    Cscale = 0.1
    C = (1.0 - adj)
    connsC = np.sum(C, axis=1)

    init_range = 0.2*np.pi
    phi_init = np.random.uniform(-init_range, init_range, size=(num_nodes,))
    cos_phi_init = np.cos(phi_init)
    sin_phi_init = np.sin(phi_init)

    lr = 0.1

    lrc = lr*(num_nodes - conns)/(num_nodes)
    lrr = Cscale*lr*conns/(num_nodes)
    tau = 500
    decay = 1 - 1/tau
    sigma = 0.1
    num_steps = 2000

    nodes = GC.OScillatoryNeuron(shape=(num_nodes,), phi=phi_init, sigma=sigma, decay=decay, lrc=lrc, lrr=lrr)
    connections = GC.GraphColorUpdate(shape=(num_nodes,), shape_mat=(num_nodes, num_nodes), B=B, C=C)
    phi_monitor = Monitor()

    nodes.cos_out.connect(connections.cos_in)
    nodes.sin_out.connect(connections.sin_in)

    connections.B_cos_out.connect(nodes.B_cos_in)
    connections.B_sin_out.connect(nodes.B_sin_in)
    connections.C_cos_out.connect(nodes.C_cos_in)
    connections.C_sin_out.connect(nodes.C_sin_in)
    phi_monitor.probe(nodes.phi, num_steps)
    
    nodes.run(condition=RunSteps(num_steps=num_steps), run_cfg=Loihi1SimCfg())
    phi_vals = phi_monitor.get_data()
    nodes.stop()
    # print(list(phi_vals.keys()))
    phi_history = phi_vals[list(phi_vals.keys())[0]]['phi']
    # phi_history = phi_vals['Process_0']['phi']

    last_phi = phi_history[-1,:]
    P, order = gen_permutation_matrix(last_phi)
    chromatic_number, min_color_blocks = get_chr(P, adj, order)
    # print("order-based chromatic number at simulation end: ", chromatic_number)
    # print("color blocks at simulation end: ", min_color_blocks)
    
    print_fr = 500
    chr_ns = []
    min_chr_n = num_nodes
    min_ind = 0
    min_chr_n_color_blocks = [[i] for i in range(num_nodes)]
    for i in range(phi_history.shape[0]):
        # if i%print_fr == print_fr-1:
        #     print("computing for iter: ", i+1)
        #     print("minimum chromatic number: ", min_chr_n)
        curr_phi = phi_history[i,:]
        P, order = gen_permutation_matrix(curr_phi)
        chr_n, chr_n_color_blocks = get_chr(P, adj, order)  # changes here
        if chr_n<min_chr_n:
            min_chr_n = chr_n
            min_ind = i
            min_chr_n_color_blocks = chr_n_color_blocks
        chr_ns.append(chr_n)
    
    print("minimum order-based chromatic number during simulation: ", min_chr_n)
    # print("color blocks at minimum chromatic number: ", min_chr_n_color_blocks)

    return min_chr_n_color_blocks

def get_color_indice_array(color_blocks, adj):
    color_indice_array = np.zeros(adj.shape[0], dtype=np.int32)
    temp_color_index = 0
    for color_block in color_blocks:
        for node in color_block:
            color_indice_array[node] = temp_color_index
        temp_color_index += 1
    num_colors = temp_color_index
    return color_indice_array, num_colors

# %%
def moe_maxcut(adj):
    G = nx.from_numpy_array(adj)
    cut, cutsize = mod_one_exchange_approximation_new(G)

    # fig, ax = plt.subplots()
    # nx.draw_circular(G, with_labels=True, node_color=cut, ax=ax)

    # cut consists of ones and zeros, where ones represent the nodes in one subgraph and zeros represent the nodes in the other subgraph
    cut1_size = np.sum(cut)
    cut0_size = len(cut) - cut1_size
    # Create two new adjacent matrices for the two subgraphs given by cut
    adj1 = np.zeros((cut1_size, cut1_size))
    adj0 = np.zeros((cut0_size, cut0_size))
    
    map_index1 = {}
    map_index0 = {}

    reverse_map = {}

    temp1 = 0
    temp0 = 0
    for i in range(len(cut)):
        
        if cut[i] == 1:
            map_index1[temp1] = i
            reverse_map[i] = (1, temp1)
            temp1 += 1
        else:
            map_index0[temp0] = i
            reverse_map[i] = (0, temp0)
            temp0 += 1
    
    for i in range(len(cut)):
        for j in range(len(cut)):
            if cut[i] == 1 and cut[j] == 1:
                adj1[reverse_map[i][1], reverse_map[j][1]] = adj[i, j]
            elif cut[i] == 0 and cut[j] == 0:
                adj0[reverse_map[i][1], reverse_map[j][1]] = adj[i, j]

    return adj1, adj0, cut, map_index1, map_index0, reverse_map

# adj1, adj0, cut, map_index1, map_index0, reverse_map = moe_maxcut(adj)
# print(adj1)
# print(adj0)
# print(cut)
# print(map_index1)
# print(map_index0)
# print(reverse_map)
# dsjc125.1.col, dsjc125.5.col, dsjc250.5.col, dsjc500.1.col, dsjc500.5.col, dsjc500.9.col, dsjc1000.1.col, dsjc1000.5.col, dsjc1000.9.col, dsjr500.1c.col, dsjr500.5.col, flat300_28_0.col, flat1000_50_0.col, flat1000_60_0.col, flat1000_76_0.col, latin_square.col, le450_25c.col, le450_25d.col, myciel6.col, myciel7.col, queen6_6.col, queen77matrix.txt, r250.5.col, r1000.1c.col, r1000.5.col

# %%
import cProfile, pstats, io
from pstats import SortKey
pr = cProfile.Profile()
pr.enable()


thresholds = [20,30,50,100]
# This attempt uses simple merging without any optimization
def graph_coloring1(adj, threshold=1000000):
    if adj.shape[0] <= threshold:
        return graph_painter(adj)
    else:
        adj1, adj0, cut, map_index1, map_index0, reverse_map = moe_maxcut(adj)
        colors1 = graph_coloring1(adj1)
        colors0 = graph_coloring1(adj0)
        colors_merged = []
        for color_block in colors1:
            temp_list = []
            for node in color_block:
                temp_list.append(map_index1[node])
            colors_merged.append(temp_list)
        
        for color_block in colors0:
            temp_list = []
            for node in color_block:
                temp_list.append(map_index0[node])
            colors_merged.append(temp_list)

    # print(colors_merged)

    return colors_merged

graph_name = 'myciel3'

# read the graph from the file
G = mat_to_graph('test_graphs/' + graph_name + '.mat')

# get the adjacency matrix of the graph
adj = nx.adjacency_matrix(G).todense()
adj = np.asarray(adj, dtype=np.int32)

# print(adj)

# get the colors of the graph
colors = graph_coloring1(adj)
color_array, num_colors = get_color_indice_array(colors, adj)
# print(colors)

# Draw the graph
# fig, ax = plt.subplots()
# nx.draw_circular(G, with_labels=True, node_color=color_array, ax=ax)
# plt.show()

pr.disable()
s = io.StringIO()
sortby = SortKey.TIME
ps = pstats.Stats(pr, stream=s).sort_stats(sortby)
ps.print_stats()
print(s.getvalue())
# Out:
# Exception ignored When destroying _lsprof profiler:
# Traceback (most recent call last):
#   File "/tmp/ipykernel_10545/3536909188.py", line 4, in <module>
# RuntimeError: Cannot install a profile function while another profile function is being installed
# minimum order-based chromatic number during simulation:  4
#          771873 function calls (771635 primitive calls) in 3.741 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     46874    2.798    0.000    2.798    0.000 {method 'acquire' of '_thread.lock' objects}
#       273    0.233    0.001    0.233    0.001 {built-in method __new__ of type object at 0x8d0b40}
#         8    0.101    0.013    0.101    0.013 {built-in method posix.fork}
#      2001    0.074    0.000    0.175    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/GraphColoringTest.py:21(get_chr)
#     22003    0.060    0.000    0.476    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/channels/pypychannel.py:161(get)
#     22003    0.057    0.000    0.588    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/channels/pypychannel.py:293(recv)
#     22003    0.042    0.000    0.042    0.000 {method 'copy' of 'numpy.ndarray' objects}
#     28049    0.036    0.000    0.036    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         1    0.025    0.025    0.611    0.611 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/runtime/runtime.py:573(get_var)
#     28045    0.024    0.000    0.072    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/numpy/core/fromnumeric.py:71(_wrapreduction)
#     28020    0.021    0.000    0.094    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2177(sum)
#      6206    0.020    0.000    2.825    0.000 /usr/lib/python3.10/threading.py:288(wait)
#       230    0.019    0.000    0.019    0.000 {built-in method posix.read}
#     22003    0.014    0.000    0.030    0.000 /usr/lib/python3.10/threading.py:359(notify)
#       101    0.013    0.000    0.013    0.000 {built-in method posix.waitpid}
#     28208    0.012    0.000    0.020    0.000 /usr/lib/python3.10/threading.py:279(_is_owned)
#     28192    0.011    0.000    0.016    0.000 /usr/lib/python3.10/queue.py:209(_qsize)
#     22027    0.011    0.000    0.014    0.000 /usr/lib/python3.10/threading.py:267(__exit__)
#     22027    0.010    0.000    0.016    0.000 /usr/lib/python3.10/threading.py:264(__enter__)
#     28045    0.009    0.000    0.009    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/numpy/core/fromnumeric.py:72(<dictcomp>)
#     22003    0.009    0.000    0.012    0.000 /usr/lib/python3.10/queue.py:217(_get)
#         8    0.009    0.001    0.009    0.001 {method 'poll' of 'select.poll' objects}
#      2001    0.008    0.000    0.013    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/GraphColoringTest.py:13(gen_permutation_matrix)
#     22026    0.005    0.000    0.005    0.000 {method '__enter__' of '_thread.lock' objects}
#     22017    0.005    0.000    0.005    0.000 {method 'release' of '_multiprocessing.SemLock' objects}
# 34126/34121    0.005    0.000    0.005    0.000 {built-in method builtins.len}
#        50    0.004    0.000    0.004    0.000 {built-in method marshal.loads}
#     28020    0.004    0.000    0.004    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2172(_sum_dispatcher)
#     36233    0.004    0.000    0.005    0.000 {built-in method builtins.isinstance}
#     22056    0.004    0.000    0.004    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/channels/watchdog.py:178(__exit__)
#     22056    0.004    0.000    0.004    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/channels/watchdog.py:175(__enter__)
#      6205    0.003    0.000    0.005    0.000 /usr/lib/python3.10/threading.py:276(_acquire_restore)
#     22003    0.003    0.000    0.003    0.000 {method 'popleft' of 'collections.deque' objects}
#     22221    0.003    0.000    0.003    0.000 {method '__exit__' of '_thread.lock' objects}
#     40512    0.003    0.000    0.003    0.000 {method 'append' of 'list' objects}
#         1    0.003    0.003    3.740    3.740 /tmp/ipykernel_10545/2622774851.py:9(graph_painter)
#      6205    0.003    0.000    0.004    0.000 /usr/lib/python3.10/threading.py:273(_release_save)
#        56    0.003    0.000    0.003    0.000 {method 'read' of '_io.BufferedReader' objects}
#        69    0.003    0.000    0.005    0.000 /usr/lib/python3.10/multiprocessing/synchronize.py:50(__init__)
#      2001    0.002    0.000    0.002    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#     28201    0.002    0.000    0.002    0.000 {method 'items' of 'dict' objects}
#      6401    0.002    0.000    0.002    0.000 {built-in method _thread.allocate_lock}
#      6935    0.001    0.000    0.001    0.000 {built-in method builtins.getattr}
#      2001    0.001    0.000    0.004    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/numpy/core/fromnumeric.py:53(_wrapfunc)
#      2001    0.001    0.000    0.005    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/numpy/core/fromnumeric.py:1025(argsort)
#        48    0.001    0.000    0.004    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/process/process.py:264(_find_attr_by_type)
#      6205    0.001    0.000    0.001    0.000 {method 'release' of '_thread.lock' objects}
#      6239    0.001    0.000    0.001    0.000 {method 'append' of 'collections.deque' objects}
#        33    0.001    0.000    0.001    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/zmq/sugar/socket.py:626(send)
#      2004    0.001    0.000    0.001    0.000 {built-in method numpy.zeros}
#     32/18    0.001    0.000    0.001    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/compiler_graphs.py:435(_find_terminal_procs_recursively)
#       452    0.001    0.000    0.002    0.000 /usr/lib/python3.10/inspect.py:801(getmodulename)
#       186    0.001    0.000    0.235    0.001 {built-in method builtins.__build_class__}
#      3325    0.001    0.000    0.001    0.000 {built-in method _abc._abc_instancecheck}
#        57    0.001    0.000    0.001    0.000 {built-in method builtins.dir}
#        24    0.001    0.000    0.001    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/channels/pypychannel.py:304(join)
#         8    0.001    0.000    0.102    0.013 /usr/lib/python3.10/multiprocessing/popen_fork.py:62(_launch)
#       224    0.001    0.000    0.001    0.000 {built-in method posix.stat}
#      3325    0.001    0.000    0.001    0.000 /usr/lib/python3.10/abc.py:117(__instancecheck__)
#        50    0.001    0.000    0.001    0.000 {built-in method posix.listdir}
#         7    0.001    0.000    0.005    0.001 /usr/lib/python3.10/multiprocessing/context.py:100(Queue)
#        57    0.001    0.000    0.001    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/compiler_graphs.py:779(<listcomp>)
#        16    0.000    0.000    0.009    0.001 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/ipykernel/iostream.py:592(flush)
#        50    0.000    0.000    0.000    0.000 {built-in method io.open_code}
#        69    0.000    0.000    0.001    0.000 /usr/lib/python3.10/random.py:519(<listcomp>)
#         8    0.000    0.000    0.113    0.014 /usr/lib/python3.10/multiprocessing/process.py:110(start)
#         7    0.000    0.000    0.255    0.036 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/compiler_graphs.py:794(_find_proc_models)
#         9    0.000    0.000    0.000    0.000 /usr/lib/python3.10/multiprocessing/util.py:186(__init__)
#         7    0.000    0.000    0.005    0.001 /usr/lib/python3.10/multiprocessing/queues.py:37(__init__)
#         9    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#        82    0.000    0.000    0.004    0.000 /usr/lib/python3.10/pkgutil.py:144(_iter_file_finder_modules)
#       452    0.000    0.000    0.001    0.000 /usr/lib/python3.10/inspect.py:805(<listcomp>)
#        24    0.000    0.000    0.002    0.000 /usr/lib/python3.10/multiprocessing/shared_memory.py:75(__init__)
#         8    0.000    0.000    0.001    0.000 /usr/lib/python3.10/multiprocessing/process.py:61(_cleanup)
#       111    0.000    0.000    0.000    0.000 {built-in method posix.close}
#       230    0.000    0.000    0.020    0.000 /usr/lib/python3.10/multiprocessing/connection.py:374(_recv)
#        69    0.000    0.000    0.001    0.000 /usr/lib/python3.10/tempfile.py:292(__next__)
#        69    0.000    0.000    0.001    0.000 /usr/lib/python3.10/random.py:506(choices)
#         1    0.000    0.000    0.152    0.152 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/runtime/runtime.py:158(initialize)
#        15    0.000    0.000    0.001    0.000 /usr/lib/python3.10/multiprocessing/connection.py:516(Pipe)
#         1    0.000    0.000    0.093    0.093 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/runtime/runtime.py:300(_build_processes)
#       262    0.000    0.000    0.001    0.000 /usr/lib/python3.10/posixpath.py:71(join)
#        33    0.000    0.000    0.002    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/ipykernel/iostream.py:259(schedule)
#        25    0.000    0.000    0.000    0.000 /usr/lib/python3.10/multiprocessing/resource_tracker.py:78(ensure_running)
#         8    0.000    0.000    0.001    0.000 /usr/lib/python3.10/multiprocessing/process.py:80(__init__)
#       129    0.000    0.000    0.000    0.000 {built-in method _abc._abc_init}
#        39    0.000    0.000    0.000    0.000 /usr/lib/python3.10/socket.py:220(__init__)
#         7    0.000    0.000    0.103    0.015 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/runtime/message_infrastructure/multiprocessing.py:114(build_actor)
#        24    0.000    0.000    0.000    0.000 {built-in method posix.pipe}
#       452    0.000    0.000    0.001    0.000 /usr/lib/python3.10/posixpath.py:140(basename)
#       109    0.000    0.000    0.014    0.000 /usr/lib/python3.10/multiprocessing/popen_fork.py:24(poll)
#      2001    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/numpy/core/fromnumeric.py:1021(_argsort_dispatcher)
#        69    0.000    0.000    0.002    0.000 /usr/lib/python3.10/multiprocessing/synchronize.py:114(_make_name)
#      2444    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/channels/pypychannel.py:91(<listcomp>)
#       129    0.000    0.000    0.233    0.002 /usr/lib/python3.10/abc.py:105(__new__)
#        20    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/ipykernel/ipkernel.py:775(_clean_thread_parent_frames)
#        50    0.000    0.000    0.009    0.000 <frozen importlib._bootstrap_external>:950(get_code)
#         7    0.000    0.000    0.000    0.000 /usr/lib/python3.10/multiprocessing/queues.py:71(_reset)
#         4    0.000    0.000    0.000    0.000 /usr/lib/python3.10/logging/__init__.py:1403(_clear_cache)
#        30    0.000    0.000    0.000    0.000 /usr/lib/python3.10/threading.py:236(__init__)
#       115    0.000    0.000    0.020    0.000 /usr/lib/python3.10/multiprocessing/connection.py:413(_recv_bytes)
#         8    0.000    0.000    0.112    0.014 /usr/lib/python3.10/multiprocessing/popen_fork.py:15(__init__)
#        76    0.000    0.000    0.000    0.000 /usr/lib/python3.10/weakref.py:165(__setitem__)
#        50    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:721(spec_from_file_location)
#       100    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:380(cache_from_source)
#        43    0.000    0.000    0.000    0.000 /usr/lib/python3.10/logging/__init__.py:228(_releaseLock)
#       149    0.000    0.000    0.000    0.000 {built-in method posix.write}
#       642    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        48    0.000    0.000    0.003    0.000 /usr/lib/python3.10/multiprocessing/context.py:80(Semaphore)
#        25    0.000    0.000    0.005    0.000 /usr/lib/python3.10/multiprocessing/connection.py:747(answer_challenge)
#      1394    0.000    0.000    0.000    0.000 /usr/lib/python3.10/inspect.py:191(isclass)
#        50    0.000    0.000    0.000    0.000 {built-in method _hashlib.hmac_new}
#         1    0.000    0.000    0.000    0.000 {built-in method io.open}
#        24    0.000    0.000    0.000    0.000 {built-in method _posixshmem.shm_open}
#         7    0.000    0.000    0.002    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/runtime/message_infrastructure/multiprocessing.py:60(__init__)
#        14    0.000    0.000    0.003    0.000 /usr/lib/python3.10/multiprocessing/context.py:65(Lock)
#       820    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#        96    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/builders/channel_builder.py:37(watch)
#        25    0.000    0.000    0.000    0.000 /usr/lib/python3.10/multiprocessing/reduction.py:38(__init__)
#        25    0.000    0.000    0.000    0.000 {method 'connect' of '_socket.socket' objects}
#        76    0.000    0.000    0.001    0.000 /usr/lib/python3.10/multiprocessing/util.py:171(register_after_fork)
#       167    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:404(parent)
#         1    0.000    0.000    0.009    0.009 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/runtime/runtime.py:209(_build_channels)
#       182    0.000    0.000    0.002    0.000 {built-in method builtins.next}
#         8    0.000    0.000    0.000    0.000 /usr/lib/python3.10/logging/__init__.py:1636(addHandler)
#        75    0.000    0.000    0.001    0.000 /usr/lib/python3.10/multiprocessing/connection.py:181(send_bytes)
#        24    0.000    0.000    0.001    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/channels/pypychannel.py:396(nbytes)
#        55    0.000    0.000    0.000    0.000 /usr/lib/python3.10/multiprocessing/connection.py:117(__init__)
#        24    0.000    0.000    0.014    0.001 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/channels/pypychannel.py:359(__init__)
#        25    0.000    0.000    0.001    0.000 /usr/lib/python3.10/multiprocessing/connection.py:623(SocketClient)
#         8    0.000    0.000    0.112    0.014 /usr/lib/python3.10/multiprocessing/context.py:278(_Popen)
#         7    0.000    0.000    0.001    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/process/process.py:163(__init__)
#        90    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/decorator.py:108(tag)
#        50    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:492(_init_module_attrs)
#       601    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/channels/pypychannel.py:248(<listcomp>)
#        57    0.000    0.000    0.001    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/compiler_graphs.py:757(_find_proc_models_in_module)
#         5    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/channels/pypychannel.py:130(send)
#        10    0.000    0.000    0.009    0.001 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/builders/channel_builder.py:109(build)
#       731    0.000    0.000    0.000    0.000 /usr/lib/python3.10/posixpath.py:41(_get_sep)
#         7    0.000    0.000    0.000    0.000 {built-in method _socket.socketpair}
#        18    0.000    0.000    0.007    0.000 /usr/lib/python3.10/threading.py:589(wait)
#        84    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:179(_get_module_lock)
#        42    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:1022(_find_and_load)
#        24    0.000    0.000    0.000    0.000 {method 'close' of 'mmap.mmap' objects}
#        69    0.000    0.000    0.000    0.000 /usr/lib/python3.10/tempfile.py:281(rng)
#         8    0.000    0.000    0.009    0.001 /usr/lib/python3.10/multiprocessing/util.py:433(_flush_std_streams)
#        82    0.000    0.000    0.004    0.000 /usr/lib/python3.10/pkgutil.py:110(iter_modules)
#        24    0.000    0.000    0.010    0.000 /usr/lib/python3.10/multiprocessing/managers.py:1356(SharedMemory)
#       150    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:132(_path_split)
#       474    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#       100    0.000    0.000    0.000    0.000 /usr/lib/python3.10/multiprocessing/connection.py:390(_send_bytes)
#        24    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/builders/channel_builder.py:61(create_watchdogs)
#         7    0.000    0.000    0.000    0.000 /usr/lib/python3.10/socket.py:650(socketpair)
#         1    0.000    0.000    0.022    0.022 /usr/lib/python3.10/multiprocessing/managers.py:535(start)
#       174    0.000    0.000    0.001    0.000 /usr/lib/python3.10/genericpath.py:39(isdir)
#         6    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/builders/py_builder.py:74(check_all_vars_and_ports_set)
#       132    0.000    0.000    0.000    0.000 /usr/lib/python3.10/threading.py:1145(ident)
#         8    0.000    0.000    0.009    0.001 /usr/lib/python3.10/multiprocessing/connection.py:917(wait)
#        82    0.000    0.000    0.009    0.000 /usr/lib/python3.10/multiprocessing/connection.py:208(recv_bytes)
#        49    0.000    0.000    0.000    0.000 /usr/lib/python3.10/threading.py:1169(is_alive)
#        69    0.000    0.000    0.000    0.000 /usr/lib/python3.10/multiprocessing/synchronize.py:90(_make_methods)
#        76    0.000    0.000    0.000    0.000 /usr/lib/python3.10/weakref.py:348(__new__)
#       601    0.000    0.000    0.000    0.000 /usr/lib/python3.10/abc.py:121(__subclasscheck__)
#        25    0.000    0.000    0.001    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2979(prod)
#        93    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/decorator.py:93(decorate_process_model)
#       138    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/process/process.py:642(__next__)
#        20    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/builders/py_builder.py:173(set_csp_ports)
#        33    0.000    0.000    0.011    0.000 /usr/lib/python3.10/multiprocessing/connection.py:246(recv)
#        33    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/ipykernel/iostream.py:138(_event_pipe)
#        53    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/process/interfaces.py:48(process)
#        50    0.000    0.000    0.000    0.000 /usr/lib/python3.10/hmac.py:66(_init_hmac)
#        28    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/networkx/classes/digraph.py:737(add_edges_from)
#        24    0.000    0.000    0.000    0.000 /usr/lib/python3.10/multiprocessing/shared_memory.py:223(close)
#         6    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/runtime/runtime.py:330(_create_external_channels)
#        50    0.000    0.000    0.003    0.000 <frozen importlib._bootstrap_external>:1070(get_data)
#        93    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/decorator.py:34(decorate_process_model)
#        50    0.000    0.000    0.000    0.000 {method '__exit__' of '_io._IOBase' objects}
#       352    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#       198    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/process/process.py:599(members)
#         1    0.000    0.000    0.006    0.006 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/runtime/runtime.py:256(_build_sync_channels)
#         7    0.000    0.000    0.100    0.014 /usr/lib/python3.10/multiprocessing/context.py:222(_Popen)
#       466    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#        50    0.000    0.000    0.000    0.000 /usr/lib/python3.10/hmac.py:38(__init__)
#       452    0.000    0.000    0.000    0.000 /usr/lib/python3.10/importlib/machinery.py:17(all_suffixes)
#        25    0.000    0.000    0.001    0.000 /usr/lib/python3.10/multiprocessing/connection.py:732(deliver_challenge)
#       619    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#        90    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/decorator.py:155(decorate_process_model)
#      59/9    0.000    0.000    3.741    0.416 {built-in method builtins.exec}
#        24    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/channels/pypychannel.py:146(join)
#       436    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#        50    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:866(is_package)
#        76    0.000    0.000    0.000    0.000 /usr/lib/python3.10/weakref.py:353(__init__)
#        84    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:100(acquire)
#         2    0.000    0.000    0.000    0.000 {built-in method _thread.start_new_thread}
#        39    0.000    0.000    0.000    0.000 /usr/lib/python3.10/socket.py:504(detach)
#        43    0.000    0.000    0.000    0.000 /usr/lib/python3.10/logging/__init__.py:219(_acquireLock)
#         1    0.000    0.000    0.001    0.001 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/runtime/runtime.py:509(join)
#        93    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/decorator.py:69(requires)
#         8    0.000    0.000    0.022    0.003 /usr/lib/python3.10/multiprocessing/process.py:142(join)
#        40    0.000    0.000    0.000    0.000 {built-in method _pickle.loads}
#       294    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         1    0.000    0.000    0.001    0.001 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/channels/pypychannel.py:89(start)
#        24    0.000    0.000    0.000    0.000 {built-in method posix.fstat}
#         1    0.000    0.000    0.029    0.029 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/runtime/runtime.py:485(stop)
#        14    0.000    0.000    0.003    0.000 /usr/lib/python3.10/multiprocessing/synchronize.py:161(__init__)
#        50    0.000    0.000    0.004    0.000 <frozen importlib._bootstrap_external>:670(_compile_bytecode)
#        25    0.000    0.000    0.007    0.000 /usr/lib/python3.10/multiprocessing/connection.py:493(Client)
#       435    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#       300    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:134(<genexpr>)
#        50    0.000    0.000    0.246    0.005 <frozen importlib._bootstrap_external>:877(exec_module)
#        18    0.000    0.000    0.000    0.000 /usr/lib/python3.10/_weakrefset.py:86(add)
#        50    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:564(module_from_spec)
#         9    0.000    0.000    0.011    0.001 /usr/lib/python3.10/multiprocessing/util.py:205(__call__)
#         7    0.000    0.000    0.004    0.001 /usr/lib/python3.10/multiprocessing/queues.py:98(get)
#       150    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:84(_unpack_uint32)
#         8    0.000    0.000    0.000    0.000 /usr/lib/python3.10/multiprocessing/process.py:189(name)
#        84    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:125(release)
#       100    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:542(_check_name_wrapper)
#        24    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/process/variable.py:46(__init__)
#        25    0.000    0.000    0.000    0.000 /usr/lib/python3.10/multiprocessing/reduction.py:48(dumps)
#        69    0.000    0.000    0.000    0.000 /usr/lib/python3.10/multiprocessing/context.py:197(get_start_method)
#       881    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#       154    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#        18    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/compiler_graphs.py:195(annotate_digraph_by_degree)
#       133    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#        50    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:585(_classify_pyc)
#        31    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#       100    0.000    0.000    0.000    0.000 /usr/lib/python3.10/multiprocessing/connection.py:365(_send)
#         7    0.000    0.000    0.001    0.000 /usr/lib/python3.10/multiprocessing/context.py:85(BoundedSemaphore)
#        96    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/channels/watchdog.py:192(create_watchdog)
#       100    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:128(<listcomp>)
#        50    0.000    0.000    0.000    0.000 {method 'digest' of '_hashlib.HMAC' objects}
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/networkx/classes/graph.py:975(add_edges_from)
#        74    0.000    0.000    0.000    0.000 /usr/lib/python3.10/weakref.py:106(remove)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/scipy/io/matlab/_miobase.py:225(_get_matfile_version)
#         7    0.000    0.000    0.001    0.000 /usr/lib/python3.10/multiprocessing/context.py:60(Pipe)
#        24    0.000    0.000    0.000    0.000 /usr/lib/python3.10/multiprocessing/shared_memory.py:40(_make_filename)
#        24    0.000    0.000    0.001    0.000 /usr/lib/python3.10/multiprocessing/resource_tracker.py:161(_send)
#         7    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/run_configs.py:168(select)
#         7    0.000    0.000    0.014    0.002 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/runtime/message_infrastructure/multiprocessing.py:74(join)
#         1    0.000    0.000    0.011    0.011 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/runtime/message_infrastructure/shared_memory_manager.py:20(shutdown)
#       100    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:126(_path_join)
#     31/29    0.000    0.000    0.000    0.000 /usr/lib/python3.10/functools.py:961(__get__)
#       122    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#        49    0.000    0.000    0.000    0.000 /usr/lib/python3.10/threading.py:1102(_wait_for_tstate_lock)
#        14    0.000    0.000    0.002    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/compiler_graphs.py:383(__init__)
#        48    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/process/process.py:273(_init_proc_member_obj)
#        93    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/decorator.py:13(implements)
#        50    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/process/process.py:604(add_members)
#        25    0.000    0.000    0.001    0.000 /usr/lib/python3.10/multiprocessing/connection.py:202(send)
#        10    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/ipykernel/ipkernel.py:790(<setcomp>)
#        10    0.000    0.000    0.000    0.000 /usr/lib/python3.10/threading.py:1478(enumerate)
#       229    0.000    0.000    0.000    0.000 /usr/lib/python3.10/multiprocessing/connection.py:134(_check_closed)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/GraphColoringSoln.py:1(<module>)
#         8    0.000    0.000    0.009    0.001 /usr/lib/python3.10/selectors.py:403(select)
#        84    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:71(__init__)
#        12    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/networkx/classes/digraph.py:489(add_nodes_from)
#       115    0.000    0.000    0.000    0.000 {built-in method _struct.unpack}
#        84    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:198(cb)
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.10/threading.py:827(__init__)
#         1    0.000    0.000    0.611    0.611 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/proc/monitor/process.py:209(get_data)
#         7    0.000    0.000    0.004    0.001 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/process/process.py:234(_post_init)
#         8    0.000    0.000    0.000    0.000 /usr/lib/python3.10/selectors.py:210(__init__)
#       552    0.000    0.000    0.000    0.000 {method 'random' of '_random.Random' objects}
#       230    0.000    0.000    0.000    0.000 {method 'write' of '_io.BytesIO' objects}
#        24    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/networkx/utils/decorators.py:766(__call__)
#         4    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/ipykernel/iostream.py:655(write)
#        24    0.000    0.000    0.010    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/runtime/message_infrastructure/shared_memory_manager.py:28(create_shared_memory)
#         1    0.000    0.000    0.001    0.001 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/runtime/runtime.py:179(_start_ports)
#        96    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/channels/watchdog.py:75(__init__)
#        48    0.000    0.000    0.002    0.000 /usr/lib/python3.10/multiprocessing/synchronize.py:125(__init__)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/GraphColoringSoln.py:23(__init__)
#        24    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/channels/pypychannel.py:196(__init__)
#        50    0.000    0.000    0.000    0.000 /usr/lib/python3.10/multiprocessing/connection.py:95(address_type)
#        24    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/channels/pypychannel.py:42(__init__)
#       164    0.000    0.000    0.000    0.000 /usr/lib/python3.10/typing.py:306(inner)
#        24    0.000    0.000    0.000    0.000 /usr/lib/python3.10/secrets.py:48(token_hex)
#       552    0.000    0.000    0.000    0.000 {built-in method math.floor}
#        50    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:618(_validate_timestamp_pyc)
#         1    0.000    0.000    0.026    0.026 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/runtime/message_infrastructure/multiprocessing.py:127(stop)
#        25    0.000    0.000    0.000    0.000 {method 'dump' of '_pickle.Pickler' objects}
#        63    0.000    0.000    0.000    0.000 /usr/lib/python3.10/multiprocessing/context.py:237(get_context)
#       100    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:391(cached)
#       100    0.000    0.000    0.000    0.000 /usr/lib/python3.10/multiprocessing/connection.py:142(_check_writable)
#       527    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/builders/interfaces.py:75(proc_model)
#        41    0.000    0.000    0.000    0.000 /usr/lib/python3.10/multiprocessing/connection.py:173(close)
#         1    0.000    0.000    0.001    0.001 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/proc/monitor/process.py:116(probe)
#       2/1    0.000    0.000    0.258    0.258 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/compiler_graphs.py:1003(_map_proc_to_model)
#         1    0.000    0.000    2.490    2.490 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/runtime/runtime.py:368(_get_resp_for_run)
#        12    0.000    0.000    0.005    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/builders/channel_builder.py:168(build)
#         1    0.000    0.000    0.016    0.016 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/runtime/runtime.py:319(_build_runtime_services)
#     78/37    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/process/ports/ports.py:173(get_src_ports)
#        50    0.000    0.000    0.000    0.000 /usr/lib/python3.10/hmac.py:167(new)
#         8    0.000    0.000    0.000    0.000 /usr/lib/python3.10/selectors.py:348(__init__)
#        50    0.000    0.000    0.000    0.000 /usr/lib/python3.10/hmac.py:151(digest)
#     68/31    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/process/ports/ports.py:291(get_dst_ports)
#        16    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/networkx/utils/decorators.py:28(not_implemented_for)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/get-pip.py:1(<module>)
#       365    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         7    0.000    0.000    0.000    0.000 /usr/lib/python3.10/multiprocessing/process.py:172(close)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/networkx/convert_matrix.py:492(to_scipy_sparse_array)
#        24    0.000    0.000    0.000    0.000 {built-in method posix.ftruncate}
#       101    0.000    0.000    0.000    0.000 /usr/lib/python3.10/_collections_abc.py:909(__iter__)
#        17    0.000    0.000    0.000    0.000 /usr/lib/python3.10/posixpath.py:150(dirname)
#         4    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/scipy/sparse/_sputils.py:264(get_index_dtype)
#      35/5    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1240(_recalculate)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/channels/pypychannel.py:243(start)
#         8    0.000    0.000    0.000    0.000 /usr/lib/python3.10/selectors.py:235(register)
#        49    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/process/interfaces.py:18(__init__)
#        15    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/process/ports/ports.py:122(_connect_forward)
#        50    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:510(_get_cached)
#        24    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/runtime/message_infrastructure/multiprocessing.py:134(channel_class)
#        43    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#        13    0.000    0.000    0.000    0.000 /usr/lib/python3.10/logging/__init__.py:1724(isEnabledFor)
#        51    0.000    0.000    0.000    0.000 {method 'update' of 'collections.OrderedDict' objects}
#        20    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/networkx/classes/function.py:569(set_node_attributes)
#        25    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/process/ports/ports.py:75(__init__)
#        50    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:357(__init__)
#        42    0.000    0.000    0.001    0.000 /usr/lib/python3.10/importlib/__init__.py:108(import_module)
#         6    0.000    0.000    0.001    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/subcompilers/py/pyproc_compiler.py:118(_create_builder_for_process)
#        16    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/networkx/classes/digraph.py:334(__init__)
#         7    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/compiler_graphs.py:905(_select_proc_models)
#         1    0.000    0.000    2.490    2.490 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/runtime/runtime.py:424(_run)
#         9    0.000    0.000    0.000    0.000 /usr/lib/python3.10/codeop.py:117(__call__)
#        18    0.000    0.000    0.000    0.000 /usr/lib/python3.10/threading.py:545(__init__)
#        25    0.000    0.000    0.003    0.000 /usr/lib/python3.10/multiprocessing/managers.py:85(dispatch)
#        49    0.000    0.000    0.000    0.000 {built-in method posix.urandom}
#         9    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#        16    0.000    0.000    0.000    0.000 /usr/lib/python3.10/threading.py:1430(current_thread)
#       3/1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/compiler_graphs.py:106(find_processes)
#         1    0.000    0.000    0.011    0.011 /usr/lib/python3.10/multiprocessing/managers.py:658(_finalize_manager)
#         8    0.000    0.000    0.022    0.003 /usr/lib/python3.10/multiprocessing/popen_fork.py:36(wait)
#         9    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/traitlets/traitlets.py:629(get)
#        50    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1089(path_stats)
#        50    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1665(_get_supported_file_loaders)
#        31    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/process/interfaces.py:75(get_next_id)
#         9    0.000    0.000    3.741    0.416 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3541(run_code)
#         7    0.000    0.000    0.005    0.001 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/process/process.py:31(__call__)
#         9    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/traitlets/traitlets.py:676(__get__)
#        51    0.000    0.000    0.000    0.000 /usr/lib/python3.10/threading.py:553(is_set)
#        42    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:1038(_gcd_import)
#        10    0.000    0.000    0.000    0.000 /usr/lib/python3.10/contextlib.py:102(__init__)
#       100    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:244(_verbose_message)
#         6    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/subcompilers/py/pyproc_compiler.py:153(_create_inport_initializers)
#        26    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#        42    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/process/process.py:586(__init__)
#        42    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:216(_lock_unlock_module)
#         7    0.000    0.000    0.000    0.000 /usr/lib/python3.10/logging/__init__.py:567(__init__)
#        55    0.000    0.000    0.000    0.000 /usr/lib/python3.10/multiprocessing/connection.py:360(_close)
#        39    0.000    0.000    0.000    0.000 {method 'setblocking' of '_socket.socket' objects}
#         1    0.000    0.000    0.029    0.029 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/process/process.py:425(stop)
#         1    0.000    0.000    0.611    0.611 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/process/variable.py:166(get)
#        74    0.000    0.000    0.000    0.000 {built-in method _weakref._remove_dead_weakref}
#       128    0.000    0.000    0.000    0.000 /usr/lib/python3.10/multiprocessing/shared_memory.py:204(buf)
#         1    0.000    0.000    0.260    0.260 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/compiler_graphs.py:620(__init__)
#        50    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:48(_new_module)
#        42    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:169(__enter__)
#        10    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/process/ports/ports.py:446(connect)
#       122    0.000    0.000    0.000    0.000 /usr/lib/python3.10/multiprocessing/connection.py:138(_check_readable)
#        92    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/compiler_graphs.py:409(_get_port_direction)
#        76    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/process/process.py:594(member_names)
#       317    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#        24    0.000    0.000    0.000    0.000 /usr/lib/python3.10/multiprocessing/shared_memory.py:209(name)
#        41    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/networkx/convert_matrix.py:1301(<genexpr>)
#        41    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/networkx/convert_matrix.py:1258(<genexpr>)
#        71    0.000    0.000    0.000    0.000 /usr/lib/python3.10/multiprocessing/util.py:48(debug)
#         1    0.000    0.000    0.001    0.001 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/proc/monitor/process.py:71(post_init)
#        30    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/process/ports/ports.py:28(is_disjoint)
#        77    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/process/interfaces.py:36(name)
#        35    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1236(_get_parent_path)
#        10    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/builders/py_builder.py:209(add_csp_port_mapping)
#         2    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/ipykernel/ipkernel.py:768(init_closure)
#        27    0.000    0.000    0.000    0.000 /usr/lib/python3.10/inspect.py:850(getmodule)
#         1    0.000    0.000    0.262    0.262 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/compiler.py:110(compile)
#         4    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/proc/dense/process.py:56(__init__)
#        41    0.000    0.000    0.000    0.000 /usr/lib/python3.10/multiprocessing/connection.py:130(__del__)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/subcompilers/channel_builders_factory.py:54(from_channel_map)
#         1    0.000    0.000    2.904    2.904 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/process/process.py:320(run)
#        50    0.000    0.000    0.237    0.005 <frozen importlib._bootstrap>:233(_call_with_frames_removed)
#        70    0.000    0.000    0.000    0.000 /usr/lib/python3.10/multiprocessing/process.py:37(current_process)
#         1    0.000    0.000    0.413    0.413 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/process/process.py:367(create_runtime)
#        10    0.000    0.000    0.000    0.000 /usr/lib/python3.10/contextlib.py:279(helper)
#       197    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.BytesIO' objects}
#         8    0.000    0.000    0.000    0.000 <string>:1(<lambda>)
#        24    0.000    0.000    0.000    0.000 /usr/lib/python3.10/secrets.py:34(token_bytes)
#     17/13    0.000    0.000    0.001    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/networkx/utils/backends.py:959(__call__)
#        24    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/process/variable.py:220(register)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/proc/dense/models.py:1(<module>)
#        44    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/networkx/classes/graph.py:1663(<genexpr>)
#         1    0.000    0.000    3.740    3.740 /tmp/ipykernel_10545/3536909188.py:9(graph_coloring1)
#         8    0.000    0.000    0.000    0.000 /usr/lib/python3.10/logging/__init__.py:872(__init__)
# ...
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#         7    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/scipy/sparse/_base.py:125(shape)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/run_conditions.py:36(__init__)
#         1    0.000    0.000    0.000    0.000 {method '_release_save' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/mapper.py:68(map_cores)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/subcompilers/interfaces.py:32(__init__)
#         2    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/process/process.py:510(get)
#         9    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/process/ports/ports.py:202(<listcomp>)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/process/ports/ports.py:259(get_outgoing_virtual_ports)
#         7    0.000    0.000    0.000    0.000 {method '__exit__' of '_multiprocessing.SemLock' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method scipy.sparse._sparsetools.csr_has_sorted_indices}
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/runtime/message_infrastructure/factory.py:13(create)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/networkx/classes/graph.py:38(__set__)
#        12    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/networkx/classes/digraph.py:1250(is_directed)
#         6    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/process/process.py:285(runtime)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/networkx/classes/digraph.py:439(add_node)
#         3    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/scipy/sparse/_coo.py:215(<genexpr>)
#         8    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/scipy/sparse/_csr.py:127(_swap)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/networkx/classes/function.py:1296(<genexpr>)
#         2    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/scipy/sparse/_compressed.py:1222(has_canonical_format)
#         2    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 /usr/lib/python3.10/collections/__init__.py:1181(__init__)
#         3    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/networkx/classes/digraph.py:383(adj)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/subcompilers/channel_map_updater.py:12(__init__)
#         1    0.000    0.000    0.000    0.000 {method '_acquire_restore' of '_thread.RLock' objects}
#         1    0.000    0.000    0.001    0.001 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/compiler.py:443(_extract_proc_builders)
#         2    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/networkx/algorithms/cycles.py:276(<listcomp>)
#         1    0.000    0.000    0.000    0.000 <class 'networkx.utils.decorators.argmap'> compilation 46:1(argmap_topological_generations_43)
#         5    0.000    0.000    0.000    0.000 {built-in method from_iterable}
#         2    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/run_configs.py:328(_is_hw_supported)
#         4    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/numpy/core/multiarray.py:503(can_cast)
#         1    0.000    0.000    0.000    0.000 /tmp/ipykernel_10545/3536909188.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/proc/monitor/process.py:10(Monitor)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/model/py/ports.py:999(get)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/compiler_graphs.py:250(<listcomp>)
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.10/collections/__init__.py:1219(__getitem__)
#         1    0.000    0.000    0.000    0.000 {method 'item' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 <class 'networkx.utils.decorators.argmap'> compilation 42:1(argmap_topological_sort_39)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/channels/watchdog.py:207(__init__)
#         4    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/numpy/core/fromnumeric.py:1976(_shape_dispatcher)
#         1    0.000    0.000    0.000    0.000 {method 'strip' of 'bytes' objects}
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/scipy/sparse/_sputils.py:96(to_native)
#         3    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/networkx/classes/graph.py:1573(is_multigraph)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/sync/protocols/loihi_protocol.py:127(runtime_service)
#         1    0.000    0.000    0.000    0.000 {built-in method math.ceil}
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/sync/domain.py:29(__init__)
#         2    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/numpy/core/_methods.py:43(_amin)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/GraphColoringSoln.py:18(OScillatoryNeuron)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/networkx/algorithms/dag.py:219(<dictcomp>)
#         6    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/builders/py_builder.py:169(<dictcomp>)
#         6    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/builders/py_builder.py:156(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/scipy/sparse/_base.py:361(format)
#         2    0.000    0.000    0.000    0.000 {method 'update' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/mapper.py:37(__init__)
#         2    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/networkx/classes/coreviews.py:53(__getitem__)
#         7    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/networkx/classes/digraph.py:1246(is_multigraph)
#         2    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/process/variable.py:109(validate_alias)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/subcompilers/py/pyproc_compiler.py:96(__del__)
#         1    0.000    0.000    0.000    0.000 {method 'intersection' of 'set' objects}
#         2    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/scipy/sparse/_compressed.py:1259(has_sorted_indices)
#         2    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/networkx/classes/reportviews.py:428(__call__)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/GraphColoringSoln.py:61(OScillatoryNeuronCart)
#         1    0.000    0.000    0.000    0.000 /usr/lib/python3.10/multiprocessing/process.py:213(authkey)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/compiler_graphs.py:660(<listcomp>)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/networkx/algorithms/dag.py:220(<listcomp>)
#         2    0.000    0.000    0.000    0.000 {method 'items' of 'collections.OrderedDict' objects}
#         4    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/proc/dense/models.py:117(PyLearningDenseModelFloat)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/GraphColoringSolnFixedPt.py:18(OScillatoryNeuronFixedPoint)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/scipy/sparse/_csr.py:55(tocsr)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/channels/watchdog.py:217(build)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/GraphColoringSoln.py:39(OScillatoryNeuronBasic)
#         2    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/scipy/sparse/_data.py:24(dtype)
#         1    0.000    0.000    0.000    0.000 /usr/lib/python3.10/multiprocessing/process.py:193(name)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/run_conditions.py:19(__init__)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/compiler.py:770(<listcomp>)
#         3    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/compiler.py:709(<listcomp>)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/GraphColoringSoln.py:130(GraphColorUpdateBasic)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/proc/dense/models.py:146(PyLearningDenseModelBitApproximate)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/networkx/classes/digraph.py:901(successors)
#         1    0.000    0.000    0.000    0.000 /usr/lib/python3.10/collections/__init__.py:1270(append)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/GraphColoringSoln.py:86(OScillatoryNeuronFixedPoint)
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.10/multiprocessing/managers.py:560(<genexpr>)
#         2    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/numpy/core/multiarray.py:85(empty_like)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/GraphColoringSoln.py:110(GraphColorUpdate)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/node.py:72(set_var_models)
#         2    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/networkx/algorithms/components/strongly_connected.py:79(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/GraphColoringSoln.py:369(PyGraphColorUpdateModel)
#         1    0.000    0.000    0.000    0.000 {built-in method sys.getdefaultencoding}
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3172(_ndim_dispatcher)
#         1    0.000    0.000    0.000    0.000 /usr/lib/python3.10/dataclasses.py:1202(<genexpr>)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/GraphColoringSolnFixedPt.py:42(GraphColorUpdateBasic)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/channels/watchdog.py:201(stop)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/GraphColoringSolnFixedPt.py:153(PyGraphColorUpdateBasicModel)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/GraphColoringSoln.py:148(GraphColorUpdateCart)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/channels/watchdog.py:198(start)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/process/process.py:502(overwrite)
#         2    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/networkx/classes/coreviews.py:299(<genexpr>)
#         1    0.000    0.000    0.000    0.000 {method '_is_owned' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/GraphColoringSoln.py:391(PyGraphColorUpdateBasicModel)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/GraphColoringSoln.py:407(PyGraphColorUpdateCartModel)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/proc/dense/models.py:50(PyDenseModelFloat)
#         1    0.000    0.000    0.000    0.000 /usr/lib/python3.10/multiprocessing/util.py:52(info)
#         2    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/networkx/classes/coreviews.py:348(<genexpr>)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/proc/dense/models.py:110(PyDenseModelBitAcc)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/compiler/subcompilers/channel_map_updater.py:29(channel_map)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/networkx/classes/graph.py:1577(is_directed)
#         1    0.000    0.000    0.000    0.000 /home/kunal/Desktop/Sem_9/DDP/Maxcut/.venv/lib/python3.10/site-packages/lava/magma/core/process/ports/ports.py:256(<listcomp>)

# %%
cnt = 0
for color in colors:
    cnt += len(color)
print(cnt)
# Out:
# 11

# %%
def graph_coloring3(adj, threshold=1000000):
    adj1, adj0, cut, map_index1, map_index0, reverse_map = moe_maxcut(adj)
    colors1 = graph_painter(adj1)
    colors0 = graph_painter(adj0)
    colors_merged = []
    for color_block in colors1:
        temp_list = []
        for node in color_block:
            temp_list.append(map_index1[node])
        colors_merged.append(temp_list)
    
    for color_block in colors0:
        temp_list = []
        for node in color_block:
            temp_list.append(map_index0[node])
        colors_merged.append(temp_list)

    # print(colors_merged)

    return colors_merged

# %%
print(num_colors)
# Out:
# 4

# %%
# Draw the graph
fig, ax = plt.subplots()
# increase the size of the figure
plt.figure(figsize=(1, 1))
nx.draw_circular(G, with_labels=True, node_color=color_array, ax=ax)
plt.show()

# %%
def graph_coloring_multi_levels(adj, thresholds):
    num_nodes = adj.shape[0]
    num_edges = np.sum(adj)/2
    density = 2*num_edges/(num_nodes*(num_nodes-1))
    print("Density: ", density)
    if density == 1:
        print("The graph is a complete graph with number of nodes: ", num_nodes)
        return
        

    for threshold in thresholds:
        print("Threshold: ", threshold)
        # pr = cProfile.Profile()
        # pr.enable()
        colors = graph_coloring1(adj, threshold)
        # pr.disable()
        # s = io.StringIO()
        # sortby = SortKey.TIME
        # ps = pstats.Stats(pr, stream=s).sort_stats(sortby)
        # ps.print_stats()
        # print(s.getvalue())
        cnt = 0
        for color in colors:
            cnt += len(color)
        print("Number of nodes colored: ", cnt)
        print("Number of colors used: ", len(colors))

        color_array, num_colors = get_color_indice_array(colors, adj)
        # print(color_array)

        # Optimization 1: Merge the color blocks with the same color
        adj_opt1 = np.zeros((num_colors, num_colors))
        for i in range (adj.shape[0]):
            for j in range (adj.shape[0]):
                if adj[i, j] == 1:
                    adj_opt1[color_array[i], color_array[j]] = 1
                    adj_opt1[color_array[j], color_array[i]] = 1

        
        graph_coloring_multi_levels(adj_opt1, thresholds)

# %%
thresholds = [50]
col_graph_names = ['dsjc125.1','dsjc125.5','dsjc250.5','dsjc500.1','dsjc500.5','dsjc500.9','dsjc1000.1','dsjc1000.5','dsjc1000.9','dsjr500.1c','dsjr500.5','flat300_28_0','flat1000_50_0','flat1000_60_0','flat1000_76_0','latin_square','le450_25c','le450_25d','myciel6','myciel7','queen6_6','r250.5','r1000.1c','r1000.5']
    # graph = 'dsjc500.1'
col_graph_names2 = ['dsjc500.1','dsjc500.5','dsjc500.9']
# col_graph_names2 = ['huck', 'myciel3', 'myciel4', 'myciel5', 'myciel6', 'myciel7','david','queen55', 'queen66','queen77']
for graph in col_graph_names2:
    print("Graph: ", graph)
    G = mat_to_graph('test_graphs/' + graph + '.mat')
    adj = nx.adjacency_matrix(G).todense()
    adj = np.asarray(adj, dtype=np.int32)
    num_nodes = adj.shape[0]
    num_edges = np.sum(adj)/2
    density = 2*num_edges/(num_nodes*(num_nodes-1))
    print("Graph: ", graph)
    print("Number of nodes: ", num_nodes)   
    print("Number of edges: ", num_edges)
    print("Density: ", density)
    graph_coloring_multi_levels(adj, thresholds)
# Out:
# Graph:  dsjc500.1
# Graph:  dsjc500.1
# Number of nodes:  500
# Number of edges:  12458.0
# Density:  0.09986372745490982
# Density:  0.09986372745490982
# Threshold:  50
# minimum order-based chromatic number during simulation:  32
# minimum order-based chromatic number during simulation:  29
# Number of nodes colored:  500
# Number of colors used:  80
# Density:  0.8462025316455696
# Threshold:  50
# minimum order-based chromatic number during simulation:  28
# minimum order-based chromatic number during simulation:  20
# Number of nodes colored:  80
# Number of colors used:  55
# Density:  0.9865319865319865
# Threshold:  50
# minimum order-based chromatic number during simulation:  27
# minimum order-based chromatic number during simulation:  19
# Number of nodes colored:  55
# Number of colors used:  47
# Density:  0.9990749306197965
# Threshold:  50
# minimum order-based chromatic number during simulation:  46
# Number of nodes colored:  47
# Number of colors used:  46
# Density:  1.0
# The graph is a complete graph with number of nodes:  46
# Graph:  dsjc500.5
# Graph:  dsjc500.5
# Number of nodes:  500
# Number of edges:  62624.0
# Density:  0.5019959919839679
# Density:  0.5019959919839679
# Threshold:  50
# minimum order-based chromatic number during simulation:  128
# minimum order-based chromatic number during simulation:  126
# Number of nodes colored:  500
# Number of colors used:  303
# Density:  0.7600375931632899
# Threshold:  50
# minimum order-based chromatic number during simulation:  107
# minimum order-based chromatic number during simulation:  93
# Number of nodes colored:  303
# Number of colors used:  235
# Density:  0.8859428987088561
# Threshold:  50
# minimum order-based chromatic number during simulation:  91
# minimum order-based chromatic number during simulation:  79
# Number of nodes colored:  235
# Number of colors used:  182
# Density:  0.9585938922955497
# Threshold:  50
# minimum order-based chromatic number during simulation:  81
# minimum order-based chromatic number during simulation:  65
# Number of nodes colored:  182
# Number of colors used:  156
# Density:  0.9791563275434243
# Threshold:  50
# minimum order-based chromatic number during simulation:  74
# minimum order-based chromatic number during simulation:  62
# Number of nodes colored:  156
# Number of colors used:  141
# Density:  0.9949341438703141
# Threshold:  50
# minimum order-based chromatic number during simulation:  70
# minimum order-based chromatic number during simulation:  59
# Number of nodes colored:  141
# Number of colors used:  130
# Density:  0.9991651759093619
# Threshold:  50
# minimum order-based chromatic number during simulation:  65
# minimum order-based chromatic number during simulation:  61
# Number of nodes colored:  130
# Number of colors used:  127
# Density:  0.9998750156230471
# Threshold:  50
# minimum order-based chromatic number during simulation:  63
# minimum order-based chromatic number during simulation:  63
# Number of nodes colored:  127
# Number of colors used:  127
# Density:  0.9998750156230471
# Threshold:  50
# minimum order-based chromatic number during simulation:  63
# minimum order-based chromatic number during simulation:  63
# Number of nodes colored:  127
# Number of colors used:  126
# Density:  1.0
# The graph is a complete graph with number of nodes:  126
# Graph:  dsjc500.9
# Graph:  dsjc500.9
# Number of nodes:  500
# Number of edges:  112437.0
# Density:  0.9012985971943888
# Density:  0.9012985971943888
# Threshold:  50
# minimum order-based chromatic number during simulation:  204
# minimum order-based chromatic number during simulation:  201
# Number of nodes colored:  500
# Number of colors used:  456
# Density:  0.9171582803161751
# Threshold:  50
# minimum order-based chromatic number during simulation:  183
# minimum order-based chromatic number during simulation:  189
# Number of nodes colored:  456
# Number of colors used:  390
# Density:  0.9420473271373014
# Threshold:  50
# minimum order-based chromatic number during simulation:  166
# minimum order-based chromatic number during simulation:  150
# Number of nodes colored:  390
# Number of colors used:  342
# Density:  0.9631973384095626
# Threshold:  50
# minimum order-based chromatic number during simulation:  150
# minimum order-based chromatic number during simulation:  133
# Number of nodes colored:  342
# Number of colors used:  295
# Density:  0.9798685575925286
# Threshold:  50
# minimum order-based chromatic number during simulation:  146
# minimum order-based chromatic number during simulation:  119
# Number of nodes colored:  295
# Number of colors used:  273
# Density:  0.9886877828054299
# Threshold:  50
# minimum order-based chromatic number during simulation:  136
# minimum order-based chromatic number during simulation:  110
# Number of nodes colored:  273
# Number of colors used:  256
# Density:  0.9933210784313725
# Threshold:  50
# minimum order-based chromatic number during simulation:  128
# minimum order-based chromatic number during simulation:  107
# Number of nodes colored:  256
# Number of colors used:  243
# Density:  0.9961908648777336
# Threshold:  50
# minimum order-based chromatic number during simulation:  121
# minimum order-based chromatic number during simulation:  105
# Number of nodes colored:  243
# Number of colors used:  234
# Density:  0.9975055940721177
# Threshold:  50
# minimum order-based chromatic number during simulation:  117
# minimum order-based chromatic number during simulation:  106
# Number of nodes colored:  234
# Number of colors used:  227
# Density:  0.9990253791275194
# Threshold:  50
# minimum order-based chromatic number during simulation:  113
# minimum order-based chromatic number during simulation:  105
# Number of nodes colored:  227
# Number of colors used:  218
# Density:  0.999873166194563
# Threshold:  50
# minimum order-based chromatic number during simulation:  109
# minimum order-based chromatic number during simulation:  107
# Number of nodes colored:  218
# Number of colors used:  216
# Density:  1.0
# The graph is a complete graph with number of nodes:  216

# %%
# IGNORE THE CODE AHEAD

# %%
def random_cut(G):
    colors = np.random.randint(2, size = G.number_of_nodes())
    cutsize = 0
    for u,v in G.edges():
        if colors[u] != colors[v]:
            cutsize += 1
    return colors, cutsize

def graph_to_mat(G, path = 'test_graphs/default2.mat'):
    # get the adjancency matrix of the graph
    adj = nx.adjacency_matrix(G).todense()
    adj = np.asarray(adj, dtype=np.int32)
    scipy.io.savemat(path, {'M': adj})   # M for matrix, to stay consistent with the .mat files we already have
    return

def mat_to_graph(path):
    mat = scipy.io.loadmat(path)
    G = nx.from_numpy_matrix(mat['M'])
    return G
# The function below would be useful to read temporary results from the subgraphs
def extract_chromatic_info(file_path):
    with open(file_path, 'r') as file:
        text = file.read()
    
    # Extract minimum order-based chromatic number using regex
    min_chromatic_number = int(re.search(r"minimum order-based chromatic number during simulation:  (\d+)", text).group(1))
    
    # Extract color blocks at minimum chromatic number using regex
    color_blocks_str = re.search(r"color blocks at minimum chromatic number:  (\[\[.*\]\])", text).group(1)
    color_blocks = eval(color_blocks_str)  # When you pass the string representation of a list of lists to eval(), 
    # it parses the string and converts it into actual Python objects (in this case, a list of lists of integers).
    
    return min_chromatic_number, color_blocks

# %%
col_graph_name = 'dsjc500.9'
G,adj,nnodes = reader.dimacs_reader("test_graphs/{}.col".format(col_graph_name))
# Save as .mat file
graph_to_mat(G, 'test_graphs/{}.mat'.format(col_graph_name))

# %%
# Example
# min_chromatic_number_without_maxcut, color_blocks = extract_chromatic_info('temp_output7.txt')

# print(min_chromatic_number_without_maxcut)
# print(color_blocks)
# G,adj,nnodes = reader.dimacs_reader("test_graphs/dsjc250.5.col")
# colors,cutsize = mod_one_exchange_approximation(G)
# colors,cutsize = gw_sdp.goemans_williamson_max_cut(G)
# colors,cutsize = random_cut(G)

# %%
def get_subgraphs(G, maxcut_colors):
    # maxcut_colors contain 0s and 1s
    # 0s are the nodes in the first set
    # 1s are the nodes in the second set
    # create two maps, one for each set
    # We proceed in ascending order over the original graph and assign the nodes to the sets
    # according to the maxcut_colors
    first_set = []
    second_set = []
    for i in range(len(maxcut_colors)):
        if maxcut_colors[i] == 0:
            first_set.append(i)
        else:
            second_set.append(i)

    # create the adjacency matrix for the subgraphs
    #
    adj = nx.adjacency_matrix(G).todense()
    adj = np.asarray(adj, dtype=np.int32)

    adj_sub1 = np.zeros((len(first_set), len(first_set)))
    adj_sub2 = np.zeros((len(second_set), len(second_set)))

    for i in range(len(first_set)):
        for j in range(len(first_set)):
            adj_sub1[i][j] = adj[first_set[i]][first_set[j]]

    for i in range(len(second_set)):
        for j in range(len(second_set)):
            adj_sub2[i][j] = adj[second_set[i]][second_set[j]]

    # create the subgraphs
    G_sub1 = nx.from_numpy_matrix(adj_sub1)
    G_sub2 = nx.from_numpy_matrix(adj_sub2)

    return G_sub1, G_sub2, first_set, second_set

# %%
def check_validity(G_sub1,G_sub2,G,color_blocks1,color_blocks2,cut,part1,part2):
    colors1 = np.zeros(G_sub1.number_of_nodes())
    colors2 = np.zeros(G_sub2.number_of_nodes())
    color_index = 0
    for i,block in enumerate(color_blocks1):
        for node in block:
            colors1[node] = color_index
        color_index += 1
    for i,block in enumerate(color_blocks2):
        for node in block:
            colors2[node] = color_index
        color_index += 1

    # check if the coloring is valid
    valid_coloring1 = True
    valid_coloring2 = True
    for edges in G_sub1.edges:
        if colors1[edges[0]] == colors1[edges[1]]:
            valid_coloring1 = False
            print("Invalid coloring for subgraph 1")
            print(edges)
    for edges in G_sub2.edges:
        if colors2[edges[0]] == colors2[edges[1]]:
            valid_coloring2 = False
            print("Invalid coloring for subgraph 2")
            print(edges)

    if(valid_coloring1):
        print("Valid coloring for subgraph 1")
    if(valid_coloring2):
        print("Valid coloring for subgraph 2")

    # combine the two colorings
    # Using two pointers approach
    i = 0
    j = 0
    k = 0

    merged_colors = np.zeros(G.number_of_nodes())
    
    while i < G_sub1.number_of_nodes() and j < G_sub2.number_of_nodes():
        if cut[k] == 0:
            merged_colors[part1[i]] = colors1[i]
            i += 1
        else:
            merged_colors[part2[j]] = colors2[j]
            j += 1
        k += 1
    while i < G_sub1.number_of_nodes():
        merged_colors[part1[i]] = colors1[i]
        i += 1
        k += 1

    while j < G_sub2.number_of_nodes():
        merged_colors[part2[j]] = colors2[j]
        j += 1
        k += 1

    # check if the coloring is valid
    valid_coloring = True
    for edges in G.edges:
        if merged_colors[edges[0]] == merged_colors[edges[1]]:
            valid_coloring = False
            print("Invalid coloring for full Graph")
            print(edges)
    if valid_coloring:
        print("Valid coloring for full Graph")
    return merged_colors


def check_reducibility(num_colors, merged_colors, G):
    color_adj = np.zeros((num_colors, num_colors))
    for edges in G.edges():
        color_adj[int(merged_colors[edges[0]])][int(merged_colors[edges[1]])] = 1
        color_adj[int(merged_colors[edges[1]])][int(merged_colors[edges[0]])] = 1
    
    temp_check = np.ones((num_colors,num_colors))-np.eye(num_colors)
    flag = np.array_equal(color_adj,temp_check)
    if flag:
        print("Not reducible")
    else:
        print("Reducible")
    
    print(color_adj)
    return flag, color_adj


def min_chromatic_number(G):
    # Use networkx's greedy_color algorithm to assign colors # Might not be complete
    color_assignment = nx.coloring.greedy_color(G, strategy="largest_first")
    
    # The chromatic number is the maximum color index used + 1
    chromatic_number = max(color_assignment.values()) + 1
    
    # Returning chromatic number and color assignment for nodes
    return chromatic_number, color_assignment

# %%
number_of_runs = 4
graph_coloring_min_colors = []
graph_coloring_with_MOE_cut_min_colors = []
graph_coloring_with_MOE_cut_min_colors_optimized = []
graph_coloring_with_random_cut_min_colors = []
graph_coloring_with_random_cut_min_colors_optimized = []
graph_coloring_with_goeman_williamson_min_colors = []
graph_coloring_with_goeman_williamson_min_colors_optimized = []
is_reducible_MOE = []
is_reducible_random_cut = []
is_reducible_goeman_williamson = []

for i in range (1, number_of_runs + 1):
    print("Running for", i, "th time")
    graph_name = 'dsjc125.5'
    G = mat_to_graph('test_graphs/' + graph_name + '.mat')
    
    # !python GraphColoringTest.py dsjc125.5 0.01 > temp_output.txt

    min_chromatic_number_without_maxcut, color_blocks = extract_chromatic_info('temp_output.txt')
    graph_coloring_min_colors.append(min_chromatic_number_without_maxcut)
    
    # Running the MOE algorithm
    cut, cutsize = mod_one_exchange_approximation(G)
    G_sub1, G_sub2, first_set, second_set = get_subgraphs(G, cut)

    cut_sub1, cutsize_sub1 = mod_one_exchange_approximation(G_sub1)
    cut_sub2, cutsize_sub2 = mod_one_exchange_approximation(G_sub2)

    graph_to_mat(G_sub1, 'test_graphs/' + graph_name + '_sub1.mat')
    graph_to_mat(G_sub2, 'test_graphs/' + graph_name + '_sub2.mat')

    # !python GraphColoringTest.py dsjc125.5_sub1 0.01 > temp_output_sub1.txt
    # !python GraphColoringTest.py dsjc125.5_sub2 0.01 > temp_output_sub2.txt

    min_chromatic_number_sub1, color_blocks_sub1 = extract_chromatic_info('temp_output_sub1.txt')
    min_chromatic_number_sub2, color_blocks_sub2 = extract_chromatic_info('temp_output_sub2.txt')

    merged_colors = check_validity(G_sub1, G_sub2, G, color_blocks_sub1, color_blocks_sub2, cut, first_set, second_set)
    graph_coloring_with_MOE_cut_min_colors.append(min_chromatic_number_sub1 + min_chromatic_number_sub2)

    flag, color_adj = check_reducibility(min_chromatic_number_sub1 + min_chromatic_number_sub2, merged_colors, G)
    is_reducible_MOE.append(flag)

    if(flag == False):
        color_graph = nx.from_numpy_matrix(color_adj)
        min_colors_optimized, color_assignment_optimized = min_chromatic_number(color_graph)
        graph_coloring_with_MOE_cut_min_colors_optimized.append(min_colors_optimized)
    else:
        graph_coloring_with_MOE_cut_min_colors_optimized.append(min_chromatic_number_sub1 + min_chromatic_number_sub2)



    # Running the random cut algorithm
    cutsize = 0
    while(cutsize == 0):  # We want to make sure that the subsets are non-empty
        cut, cutsize = random_cut(G)
        G_sub1, G_sub2, first_set, second_set = get_subgraphs(G, cut)

    

    cut_sub1, cutsize_sub1 = random_cut(G_sub1)
    cut_sub2, cutsize_sub2 = random_cut(G_sub2)

    graph_to_mat(G_sub1, 'test_graphs/' + graph_name + '_sub1.mat')
    graph_to_mat(G_sub2, 'test_graphs/' + graph_name + '_sub2.mat')

    # !python GraphColoringTest.py dsjc125.5_sub1 0.01 > temp_output_sub1.txt
    # !python GraphColoringTest.py dsjc125.5_sub2 0.01 > temp_output_sub2.txt

    min_chromatic_number_sub1, color_blocks_sub1 = extract_chromatic_info('temp_output_sub1.txt')
    min_chromatic_number_sub2, color_blocks_sub2 = extract_chromatic_info('temp_output_sub2.txt')

    merged_colors = check_validity(G_sub1, G_sub2, G, color_blocks_sub1, color_blocks_sub2, cut, first_set, second_set)
    graph_coloring_with_random_cut_min_colors.append(min_chromatic_number_sub1 + min_chromatic_number_sub2)

    flag, color_adj = check_reducibility(min_chromatic_number_sub1 + min_chromatic_number_sub2, merged_colors, G)
    is_reducible_random_cut.append(flag)

    if(flag == False):
        color_graph = nx.from_numpy_matrix(color_adj)
        min_colors_optimized, color_assignment_optimized = min_chromatic_number(color_graph)
        graph_coloring_with_random_cut_min_colors_optimized.append(min_colors_optimized)
    else:
        graph_coloring_with_random_cut_min_colors_optimized.append(min_chromatic_number_sub1 + min_chromatic_number_sub2)

        
    # Running the Goemans-Williamson algorithm
    cut, cutsize = gw_sdp.goemans_williamson_max_cut(G)
    G_sub1, G_sub2, first_set, second_set = get_subgraphs(G, cut)

    cut_sub1, cutsize_sub1 = gw_sdp.goemans_williamson_max_cut(G_sub1)
    cut_sub2, cutsize_sub2 = gw_sdp.goemans_williamson_max_cut(G_sub2)

    graph_to_mat(G_sub1, 'test_graphs/' + graph_name + '_sub1.mat')
    graph_to_mat(G_sub2, 'test_graphs/' + graph_name + '_sub2.mat')

    # !python GraphColoringTest.py dsjc125.5_sub1 0.01 > temp_output_sub1.txt
    # !python GraphColoringTest.py dsjc125.5_sub2 0.01 > temp_output_sub2.txt

    min_chromatic_number_sub1, color_blocks_sub1 = extract_chromatic_info('temp_output_sub1.txt')
    min_chromatic_number_sub2, color_blocks_sub2 = extract_chromatic_info('temp_output_sub2.txt')

    merged_colors = check_validity(G_sub1, G_sub2, G, color_blocks_sub1, color_blocks_sub2, cut, first_set, second_set)
    graph_coloring_with_goeman_williamson_min_colors.append(min_chromatic_number_sub1 + min_chromatic_number_sub2)

    flag, color_adj = check_reducibility(min_chromatic_number_sub1 + min_chromatic_number_sub2, merged_colors, G)
    is_reducible_goeman_williamson.append(flag)

    if(flag == False):
        color_graph = nx.from_numpy_matrix(color_adj)
        min_colors_optimized, color_assignment_optimized = min_chromatic_number(color_graph)
        graph_coloring_with_goeman_williamson_min_colors_optimized.append(min_colors_optimized)
    else:
        graph_coloring_with_goeman_williamson_min_colors_optimized.append(min_chromatic_number_sub1 + min_chromatic_number_sub2)

# %%
# Making a scatter plot, one for with maxcut and one for without maxcut
# only show integer ticks on the y-axis and x-axis
plt.figure()
plt.scatter(range(1, number_of_runs + 1), graph_coloring_min_colors, label = 'Without Maxcut')
plt.scatter(range(1, number_of_runs + 1), graph_coloring_with_MOE_cut_min_colors, label = 'MOE')
plt.scatter(range(1, number_of_runs + 1), graph_coloring_with_random_cut_min_colors, label = 'Random Cut')
plt.scatter(range(1, number_of_runs + 1), graph_coloring_with_goeman_williamson_min_colors, label = 'Goemans-Williamson')
plt.xticks(np.arange(1, number_of_runs + 1, 1))
plt.yticks(np.arange(min(min(graph_coloring_min_colors),
                         min(graph_coloring_with_MOE_cut_min_colors), 
                         min(graph_coloring_with_random_cut_min_colors), 
                         min(graph_coloring_with_goeman_williamson_min_colors))-1, 
                    max(max(graph_coloring_min_colors), 
                        max(graph_coloring_with_MOE_cut_min_colors), 
                        max(graph_coloring_with_random_cut_min_colors), 
                        max(graph_coloring_with_goeman_williamson_min_colors))+1))
plt.xlabel('Run Number')
plt.ylabel('Chromatic Number')
plt.legend()
plt.title('Chromatic Number with and without Maxcut')
plt.show()

# %%
# make a scatter plot for reducibility
plt.figure()
plt.scatter(range(1, number_of_runs + 1), is_reducible_MOE, label = 'With MOE')
plt.scatter(range(1, number_of_runs + 1), is_reducible_random_cut, label = 'With Random Cut')
plt.scatter(range(1, number_of_runs + 1), is_reducible_goeman_williamson, label = 'With Goemans-Williamson')
plt.xticks(range(1, number_of_runs + 2))
plt.yticks([0,1], ['Reducible', 'Not Reducible'])
plt.xlabel('Run Number')
plt.ylabel('Reducibility')
plt.legend()
plt.title('Reducibility with and without Maxcut')
plt.show()

# %%
# Making a scatter plot, one for with maxcut and one for without maxcut
# only show integer ticks on the y-axis and x-axis
plt.figure()
plt.scatter(range(1, number_of_runs + 1), graph_coloring_min_colors, label = 'Without Maxcut')
plt.scatter(range(1, number_of_runs + 1), graph_coloring_with_MOE_cut_min_colors_optimized, label = 'With MOE')
plt.scatter(range(1, number_of_runs + 1), graph_coloring_with_random_cut_min_colors_optimized, label = 'With Random Cut')
plt.scatter(range(1, number_of_runs + 1), graph_coloring_with_goeman_williamson_min_colors_optimized, label = 'With Goemans-Williamson')
plt.xticks(np.arange(1, number_of_runs + 1, 1))
plt.yticks(np.arange(min(min(graph_coloring_min_colors),
                         min(graph_coloring_with_MOE_cut_min_colors_optimized),
                         min(graph_coloring_with_random_cut_min_colors_optimized),
                         min(graph_coloring_with_goeman_williamson_min_colors_optimized))-1,
                    max(max(graph_coloring_min_colors),
                        max(graph_coloring_with_MOE_cut_min_colors_optimized),
                        max(graph_coloring_with_random_cut_min_colors_optimized),
                        max(graph_coloring_with_goeman_williamson_min_colors_optimized))+1))

plt.xlabel('Run Number')
plt.ylabel('Chromatic Number Optimized')
plt.legend()
plt.title('Chromatic Number with and without Maxcut')
plt.show()

# %%
# save all the results in a dataframe
import pandas as pd
results = pd.DataFrame({'graph_coloring_min_colors': graph_coloring_min_colors,
                        'graph_coloring_with_MOE_cut_min_colors': graph_coloring_with_MOE_cut_min_colors,
                        'graph_coloring_with_random_cut_min_colors': graph_coloring_with_random_cut_min_colors,
                        'graph_coloring_with_goeman_williamson_min_colors': graph_coloring_with_goeman_williamson_min_colors,
                        'is_reducible_MOE': is_reducible_MOE,
                        'is_reducible_random_cut': is_reducible_random_cut,
                        'is_reducible_goeman_williamson': is_reducible_goeman_williamson,
                        'graph_coloring_with_MOE_cut_min_colors_optimized': graph_coloring_with_MOE_cut_min_colors_optimized,
                        'graph_coloring_with_random_cut_min_colors_optimized': graph_coloring_with_random_cut_min_colors_optimized,
                        'graph_coloring_with_goeman_williamson_min_colors_optimized': graph_coloring_with_goeman_williamson_min_colors_optimized})

# Save by the name of the graph
results.to_csv('results_' + graph_name + '.csv')

# %%
plt.figure(figsize=(10, 6))
plt.scatter(range(1, number_of_runs + 1), graph_coloring_min_colors, label = 'Without Maxcut')
plt.scatter(range(1, number_of_runs + 1), graph_coloring_with_MOE_cut_min_colors, label = 'MOE', marker = 'o', color = 'r')
plt.scatter(range(1, number_of_runs + 1), graph_coloring_with_random_cut_min_colors, label = 'Random Cut', marker = 'o', color = 'g')
plt.scatter(range(1, number_of_runs + 1), graph_coloring_with_goeman_williamson_min_colors, label = 'Goemans-Williamson', marker = 'o', color = 'b')
plt.scatter(range(1, number_of_runs + 1), graph_coloring_with_MOE_cut_min_colors_optimized, label = 'MOE Optimized', marker = 'x', color = 'r')
plt.scatter(range(1, number_of_runs + 1), graph_coloring_with_random_cut_min_colors_optimized, label = 'Random Cut Optimized', marker = 'x', color = 'g')
plt.scatter(range(1, number_of_runs + 1), graph_coloring_with_goeman_williamson_min_colors_optimized, label = 'Goemans-Williamson Optimized', marker = 'x', color = 'b')

plt.xticks(np.arange(1, number_of_runs + 1, 1))
plt.yticks(np.arange(min(min(graph_coloring_min_colors),
                         min(graph_coloring_with_MOE_cut_min_colors_optimized),
                         min(graph_coloring_with_random_cut_min_colors_optimized),
                         min(graph_coloring_with_goeman_williamson_min_colors_optimized))-1,
                    max(max(graph_coloring_min_colors),
                        max(graph_coloring_with_MOE_cut_min_colors_optimized),
                        max(graph_coloring_with_random_cut_min_colors_optimized),
                        max(graph_coloring_with_goeman_williamson_min_colors_optimized))+1))

plt.xlabel('Run Number')
plt.ylabel('Chromatic Number Optimized')
# show legend seperately
plt.legend(loc='lower right', bbox_to_anchor=(1, 0.5))
plt.title('Chromatic Number with and without Maxcut')
plt.show()

# %%
plt.figure(figsize=(14, 6))
plt.boxplot([graph_coloring_min_colors, graph_coloring_with_MOE_cut_min_colors, graph_coloring_with_random_cut_min_colors, 
             graph_coloring_with_goeman_williamson_min_colors, graph_coloring_with_MOE_cut_min_colors_optimized, 
             graph_coloring_with_random_cut_min_colors_optimized, graph_coloring_with_goeman_williamson_min_colors_optimized])
plt.xticks([1, 2, 3, 4, 5, 6, 7], ['Without Maxcut', 'MOE', 'Random Cut', 'Goemans-Williamson',
                           'MOE Opt.', 'Random Cut Opt.', 'Goemans-Williamson Opt.'])
plt.ylabel('Chromatic Number (Both)')

plt.title('Chromatic Number with and without Maxcut')
plt.show()

# %%
# Making a box plot, one for maxcut with each method and one for without maxcut

plt.figure(figsize=(10, 6))
plt.boxplot([graph_coloring_min_colors, graph_coloring_with_MOE_cut_min_colors_optimized, graph_coloring_with_random_cut_min_colors_optimized, graph_coloring_with_goeman_williamson_min_colors_optimized])
plt.xticks([1, 2, 3, 4], ['Without Maxcut', 'MOE Opt.', 'Random Cut Opt.', 'Goemans-Williamson Opt.'])
plt.ylabel('Chromatic Number (Optimized)')

plt.title('Chromatic Number with and without Maxcut')
plt.show()

# %%
# Making a box plot, one for maxcut with each method and one for without maxcut

plt.figure(figsize=(10, 6))
plt.boxplot([graph_coloring_min_colors, graph_coloring_with_MOE_cut_min_colors, graph_coloring_with_random_cut_min_colors, graph_coloring_with_goeman_williamson_min_colors])
plt.xticks([1, 2, 3, 4], ['Without Maxcut', 'MOE', 'Random Cut', 'Goemans-Williamson'])
plt.ylabel('Chromatic Number')

plt.title('Chromatic Number with and without Maxcut')
plt.show()
